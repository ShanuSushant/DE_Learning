# %% [markdown]
# #### CHANGE DATA FEED:

# %%
# %sql
ALTER TABLE deltalakesushant.default.cloned_table
SET TBLPROPERTIES (delta.enableChangeDataFeed=True)

# %%
# %sql
SELECT * FROM deltalakesushant.default.cloned_table

# %%
# %sql
INSERT INTO deltalakesushant.default.cloned_table
VALUES (11,1000,'zz','N')

# %%
# %sql
UPDATE deltalakesushant.default.cloned_table
SET name = 'Updated Aadmi'
WHERE id = 11

# %%
# %sql
DELETE FROM deltalakesushant.default.cloned_table WHERE id = 3

# %%
# %sql
DESCRIBE HISTORY deltalakesushant.default.cloned_table

# %% [markdown]
# Output:
# ![image_1785849602192.png](./image_1785849602192.png "image_1785849602192.png")

# %%
# %sql
select * from table_changes('deltalakesushant.default.cloned_table',1)

# %% [markdown]
# Output:![image_1785849620221.png](./image_1785849620221.png "image_1785849620221.png")
