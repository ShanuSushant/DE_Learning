# %% [markdown]
# ### Schema Enforcement:
# #### Error:
# ![image_1785838305872.png](./image_1785838305872.png "image_1785838305872.png")

# %%
data = [(1,100,'aa','Y'),(2,200,'bb','Y'),(3,300,'cc','N'),(4,400,'dd','Y')]
df = spark.createDataFrame(data,['id','salary','name','isactive'])
display(df)

# %%
df.write.format("delta")\
    .mode("append")\
    .save("/Volumes/deltalakesushant/default/deltalakevol/demoSink/")

# %% [markdown]
# ### Schema Evolution:

# %%
df.write.format("delta")\
    .mode("append")\
    .option("mergeSchema",True)\
    .save("/Volumes/deltalakesushant/default/deltalakevol/demoSink/")

# %%
# %sql
SELECT * FROM delta.`/Volumes/deltalakesushant/default/deltalakevol/demoSink/`

# %%
data1 = [(1,100,'aa',10),(2,200,'bb',20),(3,300,'cc',30),(4,400,'dd',40)]
df1 = spark.createDataFrame(data1,['id','salary','name','tax'])
display(df1)

# %%
df1.write.format("delta")\
    .mode("overwrite")\
    .option("overwriteSchema",True)\
    .save("/Volumes/deltalakesushant/default/deltalakevol/demoSink/")

# %%
# %sql
SELECT * FROM delta.`/Volumes/deltalakesushant/default/deltalakevol/demoSink/`
